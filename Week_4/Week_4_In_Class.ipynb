# %%
# import numpy as np
import pandas as pd
# import plotnine as p9

# %%
import requests

url = "https://tasty.p.rapidapi.com/recipes/list"

querystring = {"from":"0","size":"20","q":"daikon"}

headers = {
    "X-RapidAPI-Key": "8e7b4eb66emsh05b4af84d6f86e3p163d2ejsn7e5cbfcbda11",
    "X-RapidAPI-Host": "tasty.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'count': 14, 'results': [{'approved_at': 1561944458, 'aspect_ratio': '1:1', 'beauty_url': 'https://img.buzzfeed.com/video-api-prod/assets/24657514c92f4d419e78747e777b1742/beauty.jpg', 'brand': None, 'brand_id': None, 'buzz_id': None, 'canonical_id': 'recipe:4326', 'compilations': [], 'cook_time_minutes': 90, 'country': 'US', 'created_at': 1535389545, 'credits': [{'is_verified': False, 'name': "Merle O'Neal", 'picture_url': '', 'type': 'internal', 'user_id': None}], 'description': 'Warm up your soul with this aromatic Vegan Pho, a delightful twist on the classic Vietnamese noodle soup. Packed with flavorful spices and fresh veggies, this comforting dish will leave you craving more!', 'draft_status': 'published', 'facebook_posts': [], 'id': 4326, 'inspired_by_url': 'https://www.connoisseurusveg.com/easy-vegan-pho/', 'instructions': [{'appliance': None, 'display_text': 'Add the dried shiitake mushrooms to a medium bowl and pour in enough water to cover. Cover with a dish towel and let hydrate for 8 hours, then rinse and drain the mushrooms 2-3 times. Set aside.', 'end_time': 8833, 'id': 38684, 'position': 1, 'start_time': 0, 'temperature': None}, {'appliance': None, 'display_text': 'In a large pan over medium heat, dry sear the onions until caramelized on both sides, 10-15 minutes. Transfer to a bowl and repeat with the daikon radish and ginger. Set aside.', 'end_time': 46500, 'id': 38685, 'position': 2, 'start_time': 10666, 'temperature': None}, {'appliance': None, 'display_text': 'Heat the oil in the pan. Add the oyster mushrooms and sauté until browned and caramelized, 6-8 minutes.', 'end_time': 54833, 'hacks': [{'end_index': 72, 'id': 13, 'match': 'browned', 'start_index': 66}], 'id': 38686, 'position': 3, 'start_time': 47000, 'temperature': None}, {'appliance': None, 'display_text': 'Add the caramelized onions, daikon, ginger, oyster mushrooms, and soaked shiitake mushrooms to a large stock pot. Add the water and bring to a boil over high heat. Reduce the heat to low heat and cover. Simmer for at least 1 hour, or up to 8 hours. The longer it cooks, the stronger the flavor of the broth will be. Season with salt to taste.', 'end_time': 82833, 'hacks': [{'end_index': 146, 'id': 18, 'match': 'boil', 'start_index': 143}], 'id': 38687, 'position': 4, 'start_time': 61000, 'temperature': None}, {'appliance': None, 'display_text': 'About 30 minutes before serving, combine the cinnamon stick, cloves, cardamom, star anise, coriander, and fennel in a fine-mesh sieve. Lower into the pot, resting the sieve on the edge, then cover and simmer for 15 minutes.', 'end_time': 99500, 'hacks': [{'end_index': 206, 'id': 17, 'match': 'simmer', 'start_index': 201}], 'id': 38688, 'position': 5, 'start_time': 86000, 'temperature': None}, {'appliance': None, 'display_text': 'Remove the spices and add the tofu to heat through, 10-15 minutes.', 'end_time': 0, 'id': 38689, 'position': 6, 'start_time': 0, 'temperature': None}, {'appliance': None, 'display_text': 'Remove the pot from the heat. Remove the onions, daikon, and ginger from the pot. (Slice and add them back to the soup, if desired.)', 'end_time': 0, 'id': 38690, 'position': 7, 'start_time': 0, 'temperature': None}, {'appliance': None, 'display_text': 'Add the noodles to serving bowls and ladle in the broth, mushrooms, and tofu.', 'end_time': 140000, 'id': 38691, 'position': 8, 'start_time': 123666, 'temperature': None}, {'appliance': None, 'display_text': 'Garnish with red onion, bean sprouts, chile peppers, a squeeze of lime, and cilantro.', 'end_time': 158500, 'id': 38692, 'position': 9, 'start_time': 143000, 'temperature': None}, {'appliance': None, 'display_text': 'Enjoy!', 'end_time': 161333, 'id': 38693, 'position': 10, 'start_time': 159000, 'temperature': None}], 'is_app_only': False, 'is_one_top': False, 'is_shoppable': True, 'is_subscriber_content': False, 'keywords': 'tasty, tasty_vegetarian', 'language': 'eng', 'name': 'How To Make Vegan Pho', 'num_servings': 6, 'nutrition': {'calori ...

# %%
daikon_recipes = pd.json_normalize(response.json(), "results")
daikon_recipes
# Out:
#     approved_at aspect_ratio  ...      brand.name      brand.slug
# 0    1561944458          1:1  ...             NaN             NaN
# 1    1570199933          1:1  ...             NaN             NaN
# 2    1582749647          1:1  ...             NaN             NaN
# 3    1533335386          1:1  ...             NaN             NaN
# 4    1544035794          1:1  ...             NaN             NaN
# 5    1540495868          1:1  ...             NaN             NaN
# 6    1553696219          1:1  ...             NaN             NaN
# 7    1528771181          1:1  ...             NaN             NaN
# 8    1616591279         16:9  ...             NaN             NaN
# 9    1558026831          1:1  ...             NaN             NaN
# 10   1568686659          1:1  ...             NaN             NaN
# 11   1561741987         None  ...             NaN             NaN
# 12   1740152780         9:16  ...             NaN             NaN
# 13   1599224363          1:1  ...  VisitSingapore  visitsingapore
#
# [14 rows x 76 columns]

# %%
pd.read_html("https://totalwarwarhammer.fandom.com/wiki/Immortal_Empires_unusual_locations")
# Out:
# [                             Name                                             Effect  ...                                   Spawn conditions Added with
#  0              Assassin's Hideout  Chance for characters in this region to gain a...  ...  Only available to Bretonnia, Dwarfs, Grand Cat...  Patch 5.2
#  1               Beached Black Ark  This location will be costly to remove  Experi...  ...  Can only appear in settlements with a port Onl...  Patch 5.2
#  2               Blessed Monastery  Chance for events to trigger related to this l...  ...  Only available to Bretonnia, Dwarfs, Grand Cat...  Patch 5.2
#  3                   Company Docks  Chance for events to trigger related to this l...  ...  Can only appear in settlements with a port Onl...  Patch 5.2
#  4                 Dwarf Mineshaft  Chance for events to trigger related to this l...  ...  Only available to The Empire, Bretonnia, Kisle...  Patch 5.2
#  5              Exquisite Vineyard  Chance for events to trigger related to this l...  ...  Only available to Bretonnia, Dwarfs, Grand Cat...  Patch 5.2
#  6              Grail Knight Grave  Control: +2  Corruption: -10 (local region) Wh...  ...  Only available to The Empire, Kislev, High Elv...  Patch 5.2
#  7   Grand Illuminator's Residence  +10% chance per turn of increasing the Fealty ...  ...  Only available to Reikland Can only appear in ...  Patch 5.2
#  8                   Healer's Camp  Chance of a plague spreading: -10% (factionwid...  ...  Only available to Bretonnia, Dwarfs, Grand Cat...  Patch 5.2
#  9                Homeless Shelter  Control: +5  Income from all buildings: -5% (l...  ...  Only available to The Empire, Bretonnia and Ki...  Patch 5.2
#  10           Painted Skin Hideout  Research rate: +10% (settlement owner)  Tzeent...  ...  Can only appear in Cathay regions[2] Only avai...  Patch 5.2
#  11                 Ranger Outpost  Hidden armies will be visible (armies in regio...  ...  Only available to Bretonnia, Dwarfs, Grand Cat...  Patch 5.2
#  12     Sacred Scythe Chapterhouse  Control: -4  Diplomatic relations: -20 with Va...  ...  Wurtbad, Stirland Only available to Bretonnia,...  Patch 5.2
#  13                 Sewer Dwelling  Control: -2  Skaven corruption: +15 (local reg...  ...  Can only appear in provinces with Skaven Corru...  Patch 5.2
#  14                 Shrine of Vaul  Improves the rarity of items gained from battl...  ...  Only available to High Elves Can only spawn in...  Patch 5.2
#  15        Silver Pinnacle Enclave  Vigour loss reduction: -10% (all armies)  Vamp...  ...  Silver Pinnacle, The Blasted Wastes Only avail...  Patch 5.2
#  16                   Snowy Hamlet  Immune to Snow attrition (all region owner arm...  ...  Can only appear in certain Empire and Kislev r...  Patch 5.2
#  17             The Counting House  Chance for events to trigger related to this l...  ...  Marienburg, The Wasteland Only available to Br...  Patch 5.2
#  18                        The Pit  Chaos Undivided corruption: +10 (local region)...  ...  Mordheim, Ostermark Only available to Bretonni...  Patch 5.2
#  19           Witch Hunter Outpost  Control: +2  Missile Strength: +10 when fighti...  ...  Only available to Bretonnia, Dwarfs, Grand Cat...  Patch 5.2
#  20      Abandoned Forge of Hashut  Chance to forge a unique item when fusing two ...  ...                                                NaN  Patch 6.3
#  21                    A Dark Gift  Diplomatic relations: -10 with all factions (s...  ...  Available to all factions except Warriors of C...  Patch 6.3
#  22             Carnival of Nurgle  Chance for characters in this region to gain a...  ...               Available to all races except Nurgle  Patch 6.3
#  23               Cathayan Caravan  Chance for events to trigger related to this l...  ...  Only available to Bretonnia, Dark Elves, Dwarf...  Patch 6.3
#  24            Covenant Laboratory  Crimson Plague: 5% chance per turn for a weak ...  ...               Available to all races except Nurgle  Patch 6.3
#  25         Crimson Skull Chambers  Khorne's Sanction: Each time you declare war o...  ...  Available to all races except Khorne and Warri...  Patch 6.3
#  26               Cult of Pleasure  Unit experience gain per turn: +100 (all armie...  ...  Available to all races except Slaanesh Require...  Patch 6.3
#  27        Dwarf Construction Site  Chance for events to trigger related to this l...  ...  Only available to Bretonnia, Dwarfs, Grand Cat...  Patch 6.3
#  28                    Elven Forts  Diplomatic relations: +40 with High Elves  Gro...  ...  Only available to Bretonnia, Dwarfs, Grand Cat...  Patch 6.3
#  29              Faulty Doomsphere  This location will be extremely costly to remo...  ...  Available to all races except Skaven Skaven co...  Patch 6.3
#  30            Ogre Mercenary Camp  Diplomatic relations: +100 with Ogre Kingdoms ...  ...        Available to all races except Ogre Kingdoms  Patch 6.3
#  31          Peg Street Pawnbroker  The Pawnbroker will periodically offer you ite...  ...  Only available to Bretonnia, Dwarfs, Grand Cat...  Patch 6.3
#  32      Primordial Spawning Pools  Upkeep: -15% for all Blessed units  Income fro...  ...                        Only available to Lizardmen  Patch 6.3
#  33          Purple Hand Safehouse  Once the Purple Hand has spread to 9 locations...  ...             Available to all races except Tzeentch  Patch 6.3
#  34                 Sartosan Vault  Chance for events to trigger related to this l...  ...  Can only appear in settlements with a port Ava...  Patch 6.3
#  35             Tower of the Cabal  The Cabal's Current Power level: % If a charac...  ...  Available to all races except Beastmen and Tze...  Patch 6.3
#  36        Underworld Sea Entrance  Underworld Sea travel time: -2 (settlement own...  ...  Can only appear in certain Naggaroth provinces...  Patch 6.3
#  37                 Unearthed Tomb  Unit capacity: +2 Tomb Guard  Unit capacity: +...  ...                       Only available to Tomb Kings  Patch 6.3
#  38          Unstable Chaos Portal  Each turn there is a 20% chance a random regio...  ...  Can only appear in provinces with 3 settlement...  Patch 6.3
#  39        Warpstone Meteor Impact  Research rate: +20 (settlement owner)  Skaven ...  ...               Available to all races except Skaven  Patch 6.3
#
#  [40 rows x 5 columns]]

# %%
df_cities2 = pd.read_html("https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population", attrs = {'class': 'wikitable sortable', "style": "text-align:center"})[0]
df_cities2
# Out:
# ---------------------------------------------------------------------------
#
# HTTPError                                 Traceback (most recent call last)
#
# Cell In[10], line 1
#
# ----> 1 df_cities2 = pd.read_html("https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population", attrs = {'class': 'wikitable sortable', "style": "text-align:center"})[0]
#
#       2 df_cities2
#
#
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/html.py:1240, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#
#    1224 if isinstance(io, str) and not any(
#
#    1225     [
#
#    1226         is_file_like(io),
#
#    (...)
#
#    1230     ]
#
#    1231 ):
#
#    1232     warnings.warn(
#
#    1233         "Passing literal html to 'read_html' is deprecated and "
#
#    1234         "will be removed in a future version. To read from a "
#
#    (...)
#
#    1237         stacklevel=find_stack_level(),
#
#    1238     )
#
# -> 1240 return _parse(
#
#    1241     flavor=flavor,
#
#    1242     io=io,
#
#    1243     match=match,
#
#    1244     header=header,
#
#    1245     index_col=index_col,
#
#    1246     skiprows=skiprows,
#
#    1247     parse_dates=parse_dates,
#
#    1248     thousands=thousands,
#
#    1249     attrs=attrs,
#
#    1250     encoding=encoding,
#
#    1251     decimal=decimal,
#
#    1252     converters=converters,
#
#    1253     na_values=na_values,
#
#    1254     keep_default_na=keep_default_na,
#
#    1255     displayed_only=displayed_only,
#
#    1256     extract_links=extract_links,
#
#    1257     dtype_backend=dtype_backend,
#
#    1258     storage_options=storage_options,
#
#    1259 )
#
#
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/html.py:983, in _parse(flavor, io, match, attrs, encoding, displayed_only, extract_links, storage_options, **kwargs)
#
#     972 p = parser(
#
#     973     io,
#
#     974     compiled_match,
#
#    (...)
#
#     979     storage_options,
#
#     980 )
#
#     982 try:
#
# --> 983     tables = p.parse_tables()
#
#     984 except ValueError as caught:
#
#     985     # if `io` is an io-like object, check if it's seekable
#
#     986     # and try to rewind it before trying the next parser
#
#     987     if hasattr(io, "seekable") and io.seekable():
#
#
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/html.py:249, in _HtmlFrameParser.parse_tables(self)
#
#     241 def parse_tables(self):
#
#     242     """
#
#     243     Parse and return all tables from the DOM.
#
#     244
#
#    (...)
#
#     247     list of parsed (header, body, footer) tuples from tables.
#
#     248     """
#
# --> 249     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#
#     250     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
#
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/html.py:806, in _LxmlFrameParser._build_doc(self)
#
#     804             pass
#
#     805     else:
#
# --> 806         raise e
#
#     807 else:
#
#     808     if not hasattr(r, "text_content"):
#
#
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/html.py:785, in _LxmlFrameParser._build_doc(self)
#
#     783 try:
#
#     784     if is_url(self.io):
#
# --> 785         with get_handle(
#
#     786             self.io, "r", storage_options=self.storage_options
#
#     787         ) as f:
#
#     788             r = parse(f.handle, parser=parser)
#
#     789     else:
#
#     790         # try to parse the input in the simplest way
#
#
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/common.py:728, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#
#     725     codecs.lookup_error(errors)
#
#     727 # open URLs
#
# --> 728 ioargs = _get_filepath_or_buffer(
#
#     729     path_or_buf,
#
#     730     encoding=encoding,
#
#     731     compression=compression,
#
#     732     mode=mode,
#
#     733     storage_options=storage_options,
#
#     734 )
#
#     736 handle = ioargs.filepath_or_buffer
#
#     737 handles: list[BaseBuffer]
#
#
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/common.py:384, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#
#     382 # assuming storage_options is to be interpreted as headers
#
#     383 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
#
# --> 384 with urlopen(req_info) as req:
#
#     385     content_encoding = req.headers.get("Content-Encoding", None)
#
#     386     if content_encoding == "gzip":
#
#     387         # Override compression based on Content-Encoding header
#
#
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/common.py:289, in urlopen(*args, **kwargs)
#
#     283 """
#
#     284 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#
#     285 the stdlib.
#
#     286 """
#
#     287 import urllib.request
#
# --> 289 return urllib.request.urlopen(*args, **kwargs)
#
#
#
# File /opt/anaconda3/lib/python3.13/urllib/request.py:189, in urlopen(url, data, timeout, context)
#
#     187 else:
#
#     188     opener = _opener
#
# --> 189 return opener.open(url, data, timeout)
#
#
#
# File /opt/anaconda3/lib/python3.13/urllib/request.py:495, in OpenerDirector.open(self, fullurl, data, timeout)
#
#     493 for processor in self.process_response.get(protocol, []):
#
#     494     meth = getattr(processor, meth_name)
#
# --> 495     response = meth(req, response)
#
#     497 return response
#
#
#
# File /opt/anaconda3/lib/python3.13/urllib/request.py:604, in HTTPErrorProcessor.http_response(self, request, response)
#
#     601 # According to RFC 2616, "2xx" code indicates that the client's
#
#     602 # request was successfully received, understood, and accepted.
#
#     603 if not (200 <= code < 300):
#
# --> 604     response = self.parent.error(
#
#     605         'http', request, response, code, msg, hdrs)
#
#     607 return response
#
#
#
# File /opt/anaconda3/lib/python3.13/urllib/request.py:533, in OpenerDirector.error(self, proto, *args)
#
#     531 if http_err:
#
#     532     args = (dict, 'default', 'http_error_default') + orig_args
#
# --> 533     return self._call_chain(*args)
#
#
#
# File /opt/anaconda3/lib/python3.13/urllib/request.py:466, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#
#     464 for handler in handlers:
#
#     465     func = getattr(handler, meth_name)
#
# --> 466     result = func(*args)
#
#     467     if result is not None:
#
#     468         return result
#
#
#
# File /opt/anaconda3/lib/python3.13/urllib/request.py:613, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#
#     612 def http_error_default(self, req, fp, code, msg, hdrs):
#
# --> 613     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
#
#
# HTTPError: HTTP Error 403: Forbidden

# %%
import requests
response = requests.get("https://statistics.calpoly.edu/content/directory")

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(response.content, "html.parser")

# %%
results = soup.find(id="Faculty")
print(results.prettify())
# Out:
# <h4 id="Faculty" name="Faculty">
#  Faculty
# </h4>

# %%
results = soup.find("p", class_ = "backtotop")

# %%
soup.find_all("table")[1]
# Out:
# <table cellspacing="0" class="directory backwhite" height="2667" summary="COSAM Dean's Office Staff" width="596"><tbody><tr><th scope="col" width="18%">
# <p>Name</p>
# </th>
# <th scope="col" width="8%">Office</th>
# <th scope="col" width="10%">Phone (805)</th>
# <th scope="col" width="20%">Email</th>
# <th scope="col" width="20%">
# <p>Office HoURS </p>
# </th>
# </tr><tr><td><strong>Lubaba Alim</strong></td>
# <td><a href="http://maps.calpoly.edu/">25-111</a></td>
# <td>756-2792</td>
# <td><a href="mailto:lfalim@calpoly.edu">lfalim@calpoly.edu</a></td>
# <td><strong>MWF</strong> 10:10-11am</td>
# </tr><tr><td><a href="/Kelly-Bodwin"><strong>Kelly Bodwin</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-106</a></td>
# <td>756-2450</td>
# <td><a href="mailto:kbodwin@calpoly.edu">kbodwin@calpoly.edu</a></td>
# <td>
# <p><strong>TR</strong> 3:10-5pm</p>
# </td>
# </tr><tr><td><a href="/Matt-Carlton"><strong>Matt Carlton</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-101</a></td>
# <td>756-7076</td>
# <td><a href="mailto:mcarlton@calpoly.edu">mcarlton@calpoly.edu</a></td>
# <td>
# <p><strong>T-F</strong> 4:30-5:30pm; only on Zoom (link in Canvas)</p>
# </td>
# </tr><tr><td>
# <p><a href="/Beth-Chance"><strong>Beth Chance</strong></a></p>
# <p>Aprendiendo español</p>
# </td>
# <td><a href="https://maps.calpoly.edu/">25
>
# <td>
# <p><a href="https://maps.calpoly.edu/">25-222</a></p>
# </td>
# <td>756-5562</td>
# <td>
# <p><a href="mailto:asabbag@calpoly.edu">asabbag@calpoly.edu</a></p>
# </td>
# <td>
# <p><strong>MW </strong>12:10-1pm; in person</p>
# <p><strong>TF</strong> 8:10-9am; Zoom (Link in Canvas)</p>
# </td>
# </tr><tr><td><a href="https://statistics.calpoly.edu/julia-schedler"><strong>Julia Schedler</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-212</a></td>
# <td>756-5877</td>
# <td><a href="mailto:jschedle@calpoly.edu">jschedle@calpoly.edu</a></td>
# <td>
# <p><b>TR </b>3:30-5pm</p>
# </td>
# </tr><tr><td><strong><a href="https://statistics.calpoly.edu/maddie-schroth">Maddie Schroth</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-223</a></td>
# <td>
# <p>756-6310</p>
# </td>
# <td><a href="mailto:mschroth@calpoly.edu">mschroth@calpoly.edu</a></td>
# <td>
# <p><strong>MW</strong> 8:10-9am; <a href="https://calendly.com/mschroth/spring-thursday-office-hours-2025-zoom-clone">Zoom</a></p>
# <p><strong>TR </strong>12:10-1pm; in person</p>
# </td>
# </tr><tr><td><strong>Sonja Schuster</strong></td>
# <td><a href="http://maps.calpoly.edu/">25-119</a></td>
# <td>756-1825</td>
# <td><a href="mailto:sschuste@calpoly.edu">sschuste@calpoly.edu</a></td>
# <td>
# <p><strong>W </strong>4:10-5pm</p>
# <p><strong>R </strong>11:10-12pm<strong> </strong></p>
# <p>only on <a href="https://calpoly.zoom.us/j/2924859737?pwd=VUw3aEwyUlJ4YkMvbUFWbGtZQStZZz09">Zoom</a></p>
# </td>
# </tr><tr><td><strong><a href="/Jeff-Sklar">Jeffrey Skl</a>ar</strong></td>
# <td>
# <p><a href="https://maps.calpoly.edu/">25-110</a></p>
# </td>
# <td>756-6353</td>
# <td><a href="mailto:jsklar@calpoly.edu">jsklar@calpoly.edu</a></td>
# <td>
# <p><strong>MW </strong>1:10-2pm</p>
# <p><strong>TR</strong> 10:10-11am</p>
# </td>
# </tr><tr><td><strong><a href="/Heather-Smith">Heather Smith</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-112</a></td>
# <td>756-6128</td>
# <td><a href="mailto:hsmith@calpoly.edu">hsmith@calpoly.edu</a></td>
# <td>
# <p><strong>TR</strong> 12:15-1pm</p>
# <p><strong>W</strong> 9:15-11am</p>
# <p><a href="https://calendly.com/hsmithcalpoly/student-zoom-15-min-mtg">Calendly</a> &amp; by appointment</p>
# </td>
# </tr><tr><td><strong><a href="https://statistics.calpoly.edu/allison-theobold">Allison Theobold</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-105</a></td>
# <td>756-5529</td>
# <td><a href="mailto:atheobol@calpoly.edu">atheobol@calpoly.edu</a></td>
# <td><strong>MR</strong> 2:10-3pm</td>
# </tr><tr><td><strong><a href="/John-Walker">John Walker</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-226</a></td>
# <td>756-7128</td>
# <td><a href="mailto:jwalker@calpoly.edu">jwalker@calpoly.edu</a></td>
# <td>
# <p>Contact Instructor</p>
# </td>
# </tr><tr><td><strong>Yi-Hui Wang</strong></td>
# <td>25-119</td>
# <td>756-1825</td>
# <td><a href="mailto:ywang59@calpoly.edu">ywang59@calpoly.edu</a></td>
# <td>
# <p><strong>W </strong>10:30-11:30am; in person</p>
# <p><strong>F</strong> 9:10-10am; Zoom</p>
# </td>
# </tr><tr><td><a href="/Immanuel-Williams"><strong>Immanuel Williams</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-113</a></td>
# <td>756-2709</td>
# <td><a href="mailto:imwillia@calpoly.edu">imwillia@calpoly.edu</a></td>
# <td><strong>TR </strong>2-4pm</td>
# </tr><tr><td><strong><a href="https://statistics.calpoly.edu/deniz-yenigun">Deniz Yenigün</a></strong><br/>
# 			Türkçe konuşuyorum</td>
# <td><a href="https://maps.calpoly.edu/">25-129</a></td>
# <td>756-0895</td>
# <td><a href="mailto:dyenigun@calpoly.edu">dyenigun@calpoly.edu</a></td>
# <td>
# <p>N/A</p>
# </td>
# </tr></tbody></table>

# %%
results.find_all("element name", class_="class name")
# Out:
# []

# %%
refined_results = results.find_all("class name", string="search text")

# %%
tables = soup.find_all("table")
len(tables)
# Out:
# 3

# %%
table = tables[1]
table
# Out:
# <table cellspacing="0" class="directory backwhite" height="2667" summary="COSAM Dean's Office Staff" width="596"><tbody><tr><th scope="col" width="18%">
# <p>Name</p>
# </th>
# <th scope="col" width="8%">Office</th>
# <th scope="col" width="10%">Phone (805)</th>
# <th scope="col" width="20%">Email</th>
# <th scope="col" width="20%">
# <p>Office HoURS </p>
# </th>
# </tr><tr><td><strong>Lubaba Alim</strong></td>
# <td><a href="http://maps.calpoly.edu/">25-111</a></td>
# <td>756-2792</td>
# <
calpoly.edu</a></td>
# <td>
# <p><strong>W </strong>4:10-5pm</p>
# <p><strong>R </strong>11:10-12pm<strong> </strong></p>
# <p>only on <a href="https://calpoly.zoom.us/j/2924859737?pwd=VUw3aEwyUlJ4YkMvbUFWbGtZQStZZz09">Zoom</a></p>
# </td>
# </tr><tr><td><strong><a href="/Jeff-Sklar">Jeffrey Skl</a>ar</strong></td>
# <td>
# <p><a href="https://maps.calpoly.edu/">25-110</a></p>
# </td>
# <td>756-6353</td>
# <td><a href="mailto:jsklar@calpoly.edu">jsklar@calpoly.edu</a></td>
# <td>
# <p><strong>MW </strong>1:10-2pm</p>
# <p><strong>TR</strong> 10:10-11am</p>
# </td>
# </tr><tr><td><strong><a href="/Heather-Smith">Heather Smith</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-112</a></td>
# <td>756-6128</td>
# <td><a href="mailto:hsmith@calpoly.edu">hsmith@calpoly.edu</a></td>
# <td>
# <p><strong>TR</strong> 12:15-1pm</p>
# <p><strong>W</strong> 9:15-11am</p>
# <p><a href="https://calendly.com/hsmithcalpoly/student-zoom-15-min-mtg">Calendly</a> &amp; by appointment</p>
# </td>
# </tr><tr><td><strong><a href="https://statistics.calpoly.edu/allison-theobold">Allison Theobold</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-105</a></td>
# <td>756-5529</td>
# <td><a href="mailto:atheobol@calpoly.edu">atheobol@calpoly.edu</a></td>
# <td><strong>MR</strong> 2:10-3pm</td>
# </tr><tr><td><strong><a href="/John-Walker">John Walker</a></strong></td>
# <td><a href="https://maps.calpoly.edu/">25-226</a></td>
# <td>756-7128</td>
# <td><a href="mailto:jwalker@calpoly.edu">jwalker@calpoly.edu</a></td>
# <td>
# <p>Contact Instructor</p>
# </td>
# </tr><tr><td><strong>Yi-Hui Wang</strong></td>
# <td>25-119</td>
# <td>756-1825</td>
# <td><a href="mailto:ywang59@calpoly.edu">ywang59@calpoly.edu</a></td>
# <td>
# <p><strong>W </strong>10:30-11:30am; in person</p>
# <p><strong>F</strong> 9:10-10am; Zoom</p>
# </td>
# </tr><tr><td><a href="/Immanuel-Williams"><strong>Immanuel Williams</strong></a></td>
# <td><a href="https://maps.calpoly.edu/">25-113</a></td>
# <td>756-2709</td>
# <td><a href="mailto:imwillia@calpoly.edu">imwillia@calpoly.edu</a></td>
# <td><strong>TR </strong>2-4pm</td>
# </tr><tr><td><strong><a href="https://statistics.calpoly.edu/deniz-yenigun">Deniz Yenigün</a></strong><br/>
# 			Türkçe konuşuyorum</td>
# <td><a href="https://maps.calpoly.edu/">25-129</a></td>
# <td>756-0895</td>
# <td><a href="mailto:dyenigun@calpoly.edu">dyenigun@calpoly.edu</a></td>
# <td>
# <p>N/A</p>
# </td>
# </tr></tbody></table>

# %%
# initialize an empty list
rows = []

# iterate over all rows in the faculty table
for faculty in table.find_all("tr")[1:]:

    # Get all the cells (<td>) in the row.
    cells = faculty.find_all("td")

    # The information we need is the text between tags.

    # Find the the name of the faculty in cell[0]
    # which for most faculty is contained in the <strong> tag
    name_tag = cells[0].find("strong") or cells[0]
    name = name_tag.text

    # Find the office of the faculty in cell[1]
    # which for most faculty is contained in the <a> tag
    link = cells[1].find("a") or cells[1]
    office = link.text

    # Find the email of the faculty in cell[3]
    # which for most faculty is contained in the <a> tag
    email_tag = cells[3].find("a") or cells[3]
    email = email_tag.text

    # Append this data.
    rows.append({
        "name": name,
        "office": office,
        "email": email
    })

# %%
pd.DataFrame(rows)
# Out:
#                  name  office                 email
# 0         Lubaba Alim  25-111    lfalim@calpoly.edu
# 1        Kelly Bodwin  25-106   kbodwin@calpoly.edu
# 2        Matt Carlton  25-101  mcarlton@calpoly.edu
# 3         Beth Chance  25-235   bchance@calpoly.edu
# 4          Nian Cheng  25-119    ncheng@calpoly.edu
# 5       Olga Dekhtyar     25-  odekhtya@calpoly.edu
# 6       Sinem Demirci  25-213  sdemirci@calpoly.edu
# 7           Jimmy Doi  25-108      jdoi@calpoly.edu
# 8        Samuel Frame  25-121    sframe@calpoly.edu
# 9         Frank Giron  25-207   frgiron@calpoly.edu
# 10       Hunter Glanz  25-111    hglanz@calpoly.edu
# 11    Billie-Jo Grant  25-119  bgrant02@calpoly.edu
# 12      Bret Holladay  25-122  bahollad@calpoly.edu
# 13           Mike Ion  25-216      mion@calpoly.edu
# 14   Felicia Korengel  25-215  fkorenge@calpoly.edu
# 15       Vance Larsen  25-129  vjlarsen@calpoly.edu
# 16         Ulric Lund  25-214     ulund@calpoly.edu
# 17     Charlotte Mann  25-201    czmann@calpoly.edu
# 18    Karen McGaughey  25-102  kmcgaugh@calpoly.edu
# 19     James Oksanish  25-216  joksanis@calpoly.edu
# 20       Zoe Rehnberg  25-109  zrehnber@calpoly.edu
# 21         Steve Rein  25-234     srein@calpoly.edu
# 22     Emily Robinson  25-103  erobin17@calpoly.edu
# 23         Kevin Ross  25-237    kjross@calpoly.edu
# 24           Soma Roy  25-104     soroy@calpoly.edu
# 25        Trevor Ruiz  25-236   truiz01@calpoly.edu
# 26     Anelise Sabbag  25-222   asabbag@calpoly.edu
# 27     Julia Schedler  25-212  jschedle@calpoly.edu
# 28     Maddie Schroth  25-223  mschroth@calpoly.edu
# 29     Sonja Schuster  25-119  sschuste@calpoly.edu
# 30      Jeffrey Sklar  25-110    jsklar@calpoly.edu
# 31      Heather Smith  25-112    hsmith@calpoly.edu
# 32   Allison Theobold  25-105  atheobol@calpoly.edu
# 33        John Walker  25-226   jwalker@calpoly.edu
# 34        Yi-Hui Wang  25-119   ywang59@calpoly.edu
# 35  Immanuel Williams  25-113  imwillia@calpoly.edu
# 36      Deniz Yenigün  25-129  dyenigun@calpoly.edu

# %%
# Now with phone num

# initialize an empty list
rows = []

# iterate over all rows in the faculty table
for faculty in table.find_all("tr")[1:]:

    # Get all the cells (<td>) in the row.
    cells = faculty.find_all("td")

    # The information we need is the text between tags.

    # Find the the name of the faculty in cell[0]
    # which for most faculty is contained in the <strong> tag
    name_tag = cells[0].find("strong") or cells[0]
    name = name_tag.text

    # Find the office of the faculty in cell[1]
    # which for most faculty is contained in the <a> tag
    link = cells[1].find("a") or cells[1]
    office = link.text

    # Find the phone of the faculty in cell[2]
    # which for most faculty is contained in the <a> tag
    phone_tag = cells[2].find("p") or cells[2]
    phone = phone_tag.text

    # Find the email of the faculty in cell[3]
    # which for most faculty is contained in the <a> tag
    email_tag = cells[3].find("a") or cells[3]
